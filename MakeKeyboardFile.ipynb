# %%
from donut import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
# %matplotlib inline

w = cruller.WordList()
w.LoadFromFile("/Users/Rylan/cisc/creamTeam/wordLists/WordList_100000_combined_check.dat")

# %%
k = bearclaw.MakeDvorakKeyboard()
k.RemoveKey('.')
bearclaw.DrawKeyboard(k,figsize=(8,4),wordlist=w,colormap=mpl.cm.Reds)

# %%
#k.SaveToFile('/Users/Rylan/cisc/creamTeam/keyboardFiles/DvorakKeyboard.dat')

# %%
#k2 = bearclaw.MakeDvorakKeyboard()
#bearclaw.DrawKeyboard(k2)
#k2.LoadFromFile('/Users/Rylan/cisc/creamTeam/keyboardFiles/DvorakKeyboard.dat')

# %%
#bearclaw.DrawKeyboard(k2)
